# %% [markdown]
# #Deven Hurt

# %%
# %matplotlib inline
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy

data = pd.read_csv('BaselineData.csv', index_col=0)
data.head()
# Out:
#        Gender  Age  Race  ServedInMilitary  CountryofBirth  EducationLevel  \
# SEQN
# 73557       1   69     4                 1               1               3
# 73558       1   54     3                 2               1               3
# 73559       1   72     3                 1               1               4
# 73562       1    9     3                 0               1               0
# 73565       2   73     3                 2               1               5
#
#        MaritalStatus  HouseholdIncome  FamilyIncome  ChildrenInHouse  \
# SEQN
# 73557              4                4             4                0
# 73558              1                7             7                2
# 73559              1               10            10                0
# 73562              0                9             9                2
# 73565              1               15            15                0
#
#        QuantitiyofAlcohol  PerUnitTime  ShortnessOfBreath  Asthma  Exercise  \
# SEQN
# ...

# %%
data.shape
# Out:
# (10175, 18)

# %%
# visualize the relationship between the features and the response using scatterplots
fig, axs = plt.subplots(1, 2, sharey=True)
data.plot(kind='scatter', x='Smoking', y='HouseholdIncome', ax=axs[0], figsize=(16, 8))
data.plot(kind='scatter', x='Smoking', y='AgeStarted', ax=axs[1])

# %%
# this is the standard import if you're using "formula notation" (similar to R)
import statsmodels.formula.api as smf

# create a fitted model in one line
lm = smf.ols(formula='Smoking ~ Age + MaritalStatus + ServedInMilitary + Asthma + AgeStarted + CountryofBirth + EducationLevel + HouseholdIncome + Exercise + Race + SmokedBefore', data=data).fit()

# print the coefficients
lm.params
# Out:
# Intercept           1.479497
# Age                 0.003474
# MaritalStatus      -0.012781
# ServedInMilitary   -0.047126
# Asthma              0.001223
# AgeStarted          0.000490
# CountryofBirth      0.004009
# EducationLevel      0.009612
# HouseholdIncome     0.000473
# Exercise           -0.030717
# Race               -0.005639
# SmokedBefore        0.011434
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Smoking   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                     742.1
# Date:                Tue, 05 Dec 2017   Prob (F-statistic):               0.00
# Time:                        18:38:56   Log-Likelihood:                -40.524
# No. Observations:               10175   AIC:                             105.0
# Df Residuals:                   10163   BIC:                             191.8
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
# create a fitted model in one line
lm = smf.ols(formula='Gender ~ Smoking + Age + MaritalStatus + ServedInMilitary + Asthma + AgeStarted + CountryofBirth + EducationLevel + HouseholdIncome + Exercise + Race + SmokedBefore', data=data).fit()

# print the coefficients
lm.params
# Out:
# Intercept           1.351045
# Smoking            -0.026840
# Age                -0.000492
# MaritalStatus       0.000589
# ServedInMilitary    0.067895
# Asthma             -0.018548
# AgeStarted          0.000197
# CountryofBirth     -0.002471
# EducationLevel     -0.009304
# HouseholdIncome    -0.001106
# Exercise            0.050838
# Race               -0.003528
# SmokedBefore        0.006331
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Gender   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     28.58
# Date:                Tue, 05 Dec 2017   Prob (F-statistic):           6.29e-65
# Time:                        19:15:00   Log-Likelihood:                -7214.7
# No. Observations:               10175   AIC:                         1.446e+04
# Df Residuals:                   10162   BIC:                         1.455e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
